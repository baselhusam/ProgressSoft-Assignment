# %%
# Import packages
from ultralytics import YOLO
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Using `haarcascade_frontalface_default` pre-trained model

# %%
def blur_face(img_path, blured_img_name = 'cascade_output.jpg', cascade_classifier = ".\pretrained_models\haarcascade_frontalface_default.xml", 
              scale_factor=1.1, min_neighbors=3, min_size=(30,30), blur_kernel_size=(25,25), blur_level=100, return_bb = False):

    """
    Blurs faces in the input image using the specified pre-trained Haar cascade classifier.

    Args:
    - img_path: string. Path to the input image.
    - blured_img_name: string. Name of the output blurred image file (default: 'output.jpg').
    - cascade_classifier: string. Path to the pre-trained Haar cascade classifier XML file (default: 'pre-trained models/haarcascade_frontalface_default.xml').
    - scale_factor: float. Specifies how much the image size is reduced at each image scale (default: 1.1).
    - min_neighbors: int. Specifies the number of neighbors a region needs to have to be considered as a face (default: 3).
    - min_size: tuple of ints. Specifies the minimum size for a detected region to be considered as a face (default: (30, 30)).
    - blur_kernel_size: tuple of ints. Specifies the kernel size for Gaussian blur (default: (25, 25)).
    - blur_level: int. Specifies the level of blur to be applied to the face (default: 100).
    - return_bb: boolean. if true, return the bounding box cordinate, if false nothing

    Returns: by default
    None.

    Raises:
    - IOError: If the input image cannot be loaded or the face cascade classifier XML file cannot be loaded.

    Examples:
    - blur_face('test_img.jpg', 'blurred_img.jpg'): blurs faces in 'test_img.jpg' and saves the output as 'blurred_img.jpg'.
    pre-trained models\haarcascade_frontalface_default.xml
    """


    # Load the input image
    img = cv2.imread(img_path)

    # Check if the image loaded correctly
    if type(img) == None:
        raise IOError("Unable toe load the image")


    # Load the face detection cascade
    face_cascade = cv2.CascadeClassifier(cascade_classifier)

    # Check if the cascade classifier is loaded correctly
    if face_cascade.empty():
        raise IOError('Unable to load the face cascade classifier xml file')


    # Convert the input image to grayscale
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray_img, scaleFactor=scale_factor, minNeighbors=min_neighbors, minSize=min_size)

    # Loop over all the faces and blur them
    for (x, y, w, h) in faces:

        # Create a region of interest (ROI) around the face
        region = img[y:y+h, x:x+w]

        # Apply Gaussian blur to the ROI
        blurred_region = cv2.GaussianBlur(region, blur_kernel_size, blur_level)

        # Replace the original ROI with the blurred ROI
        img[y:y+h, x:x+w] = blurred_region


    # Save the output image
    cv2.imwrite(blured_img_name, img)

    # if returning bounding box 
    if return_bb:
        return x, y, w + x, h + y


blur_face(".\\faces\\faces\\face7.jpg")

img = cv2.imread('cascade_output.jpg')
cv2.imshow("Cascade Classifier", img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ## Using `YOLO v8`

# %%
def yolo_face_blur(img_path, out_img_name = "Yolo_output.jpg",weights_path=".\\pretrained_models\YOLO_Model.pt",
                   blur_kernel_size=(25,25), blur_level=100, return_bb = False ):
    
    """
    Applies blurring to detected faces in an image using a YOLO face detection model.

    Args:
        img_path (str): Path to the input image to be processed.
        out_img_name (str, optional): Name of the output image file to be saved after processing. Defaults to "model2.jpg".
        weights_path (str, optional): Path to the pre-trained YOLO model weights. Defaults to ".\\pretrained_models\YOLO_Model.pt".
        blur_kernel_size (tuple, optional): Kernel size for Gaussian blur. Defaults to (25, 25).
        blur_level (int, optional): Blur level for Gaussian blur. Defaults to 100.
        return_bb: boolean. if true, return the bounding box cordinate, if false nothing
        
    Returns: by defualt
        None.

    """

    # Build the model
    model = YOLO('yolov8n.pt')
    model = YOLO(weights_path)

    # start detecting
    results = model(img_path)
    img = cv2.imread(img_path)

    # loop over detections
    for result in results:
        
        # get the bounding boxes results
        boxes = result.boxes

        if boxes:

            # loop over each box for each detect
            for box in boxes:

                # assigning the cordinate for the bounding box
                bouding_cordinate = box.xyxy
                x1, y1, x2, y2 = ( int(bouding_cordinate[0,0].item()), int(bouding_cordinate[0,1].item()), 
                                   int(bouding_cordinate[0,2].item()), int(bouding_cordinate[0,3].item()) )

                # delete all the negative cordinates
                x1, y1, x2, y2 = max(x1,0), max(y1, 0), max(x2, 0), max(y2, 0)

                # select the region & apply Gaussian Blur & put it on the original image
                region = img[y1:y2, x1:x2]
                blurred_region = cv2.GaussianBlur(region, blur_kernel_size, blur_level)
                img[y1:y2, x1:x2] = blurred_region


    # Save the image
    cv2.imwrite(out_img_name, img)
    
    # if returning bounding box 
    if return_bb:
        return x1, y1, x2, y2

yolo_face_blur(".\\faces\\faces\\face3.jpg")

img = cv2.imread('Yolo_output.jpg')
cv2.imshow("Yolov8", img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\faces\faces\face3.jpg: 448x640 11 faces, 94.9ms
# Speed: 1.0ms pre-process, 94.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# #### Between the two models

# %%
def calculate_iou(box1, box2):
    """
    Calculate intersection over union (IoU) between two bounding boxes
    """
    x1 = max(box1[0], box2[0])
    y1 = max(box1[1], box2[1])
    x2 = min(box1[2], box2[2])
    y2 = min(box1[3], box2[3])
    intersection = max(0, x2 - x1) * max(0, y2 - y1)
    area1 = (box1[2] - box1[0]) * (box1[3] - box1[1])
    area2 = (box2[2] - box2[0]) * (box2[3] - box2[1])
    union = area1 + area2 - intersection
    iou = intersection / union
    return iou

img_path = ".\\faces\\faces\\face2.jpg"
box1 = blur_face(img_path, return_bb=True)
box2 = yolo_face_blur(img_path, return_bb=True)
print(box1)
print(box2)
print("The IOU between the models is: ", calculate_iou(box1, box2))
# Out:
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\faces\faces\face2.jpg: 480x640 1 face, 92.8ms
# Speed: 1.0ms pre-process, 92.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# (152, 73, 309, 230)
# (144, 56, 322, 262)
# The IOU between the models is:  0.6722210101450856

# %%
def yolo_box(img_path, weights_path=".\\pretrained_models\YOLO_Model.pt"):
    """
    funcion returns the detecting bounding boxes for the yolo model

    Args:
        img_path (str): the path for the image
        weights_path (str, optional): the path for the weights. Defaults to ".\pretrained_models\YOLO_Model.pt".

    Returns:
        tuple: detection bouding boxes
    """

    model = YOLO('yolov8n.pt')
    model = YOLO(weights_path)

    results = model(img_path)
    img = cv2.imread(img_path)

    the_box = []
    for result in results:
        boxes = result.boxes
        if boxes:
            for box in boxes:
                bouding_cordinate = box.xyxy
                
                x1, y1, x2, y2 = ( int(bouding_cordinate[0,0].item()), int(bouding_cordinate[0,1].item()), 
                                   int(bouding_cordinate[0,2].item()), int(bouding_cordinate[0,3].item()) )

                x1, y1, x2, y2 = max(x1,0), max(y1, 0), max(x2, 0), max(y2, 0)
                the_box.append([0, x1, y1, x2, y2]) 

    return the_box

# %%
def cascade_box(img_path, cascade_classifier = ".\pretrained_models\haarcascade_frontalface_default.xml"):
    """
    function return the detecting bounding box for the haar cascade pre-trained model

    Args:
        img_path (str): path for the image
        cascade_classifier (str, optional): path for the pretrained model. Defaults to ".\pretrained_models\haarcascade_frontalface_default.xml".

    Returns:
        tuple: detection bounding boxes
    """

    img = cv2.imread(img_path)
    face_cascade = cv2.CascadeClassifier(cascade_classifier)
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray_img, scaleFactor=1.1, minNeighbors=3, minSize=(30,30))
    out_box = []

    for (x, y, w, h) in faces:
        
        out_box.append([0,x,y,w,h])

    return out_box

# %%
def compute_iou_matrix(boxes_true, boxes_pred):
    """
    Computes the IoU matrix between the true and predicted bounding boxes.
    :param boxes_true: numpy array of shape (n_true_boxes, 5) where each row is (label, x_min, y_min, x_max, y_max)
    :param boxes_pred: numpy array of shape (n_pred_boxes, 5) where each row is (label, x_min, y_min, x_max, y_max)
    :return: numpy array of shape (n_true_boxes, n_pred_boxes) representing the IoU matrix
    """
    # Compute the intersection areas
    x_min = np.maximum(boxes_true[:, 1].reshape(-1, 1), boxes_pred[:, 1].reshape(1, -1))
    y_min = np.maximum(boxes_true[:, 2].reshape(-1, 1), boxes_pred[:, 2].reshape(1, -1))
    x_max = np.minimum(boxes_true[:, 3].reshape(-1, 1), boxes_pred[:, 3].reshape(1, -1))
    y_max = np.minimum(boxes_true[:, 4].reshape(-1, 1), boxes_pred[:, 4].reshape(1, -1))
    intersection_area = np.maximum(x_max - x_min, 0) * np.maximum(y_max - y_min, 0)

    # Compute the union areas
    area_true = (boxes_true[:, 3] - boxes_true[:, 1]) * (boxes_true[:, 4] - boxes_true[:, 2])
    area_pred = (boxes_pred[:, 3] - boxes_pred[:, 1]) * (boxes_pred[:, 4] - boxes_pred[:, 2])
    union_area = area_true.reshape(-1, 1) + area_pred.reshape(1, -1) - intersection_area

    # Compute the IoU matrix
    iou_matrix = intersection_area / union_area

    return iou_matrix

# %%
def evaluate_model(ground_truth_path, bb_model_func, iou_threshold):
    
    # Get list of image paths
    image_paths = [os.path.join(ground_truth_path, 'images', filename) for filename in os.listdir(os.path.join(ground_truth_path, 'images')) if filename.endswith('.jpg')]

    # Loop through images and compute metrics
    true_positives = 0
    false_positives = 0
    false_negatives = 0
    total_iou = 0
    total_ground_truth_boxes = 0

    for image_path in image_paths[:100]:
        
        # Load image and ground truth boxes
        image = cv2.imread(image_path)
        label_path = os.path.join(ground_truth_path, 'labels', os.path.splitext(os.path.basename(image_path))[0] + '.txt')
        with open(label_path, 'r') as f:
            ground_truth_boxes = np.array([list(map(float, line.strip().split())) for line in f])

        # Get predicted boxes and convert to numpy array
        predicted_boxes = bb_model_func(image_path)
        predicted_boxes = np.array(predicted_boxes) / image.shape[0]

        if ground_truth_boxes != []:

            iou_matrix = compute_iou_matrix(ground_truth_boxes, predicted_boxes)
            iou_matrix = np.where(iou_matrix >= iou_threshold, 1, 0)

            # Compute true positives, false positives, and false negatives
            true_positives += np.sum(np.sum(iou_matrix, axis=0) == 1)
            false_positives += np.sum(np.sum(iou_matrix, axis=1) == 0)
            false_negatives += np.sum(np.sum(iou_matrix, axis=0) == 0)
            total_iou += np.sum(np.max(iou_matrix, axis=0))
            total_ground_truth_boxes += len(ground_truth_boxes)

    # Compute precision, recall, and IoU
    precision = true_positives / (true_positives + false_positives)
    recall = true_positives / (true_positives + false_negatives)
    iou = total_iou / total_ground_truth_boxes

    return precision, recall, iou

# %%
precision, recall, iou = evaluate_model(".\\roboflow_data\\test", yolo_box,0.1)
# Out:
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\-I1-MS09uaqsLdGTFkgnS0Rcg1mmPyAj95ySg_eckoM_jpeg_jpg.rf.ca3d216ca28be32265e365299a0af4b6.jpg: 640x640 3 faces, 107.0ms
# Speed: 1.0ms pre-process, 107.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\0ad90195-cd77-489e-bf85-08c83b80d3e0_jpg.rf.3317b17670bf4318a3b12a9805730774.jpg: 640x640 6 faces, 114.9ms
# Speed: 0.0ms pre-process, 114.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\1125506397_15801322206131n_jpg.rf.e15d50e045c169dc1c03cb1c926f90b9.jpg: 640x640 8 faces, 109.8ms
# Speed: 1.0ms pre-process, 109.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\1196686205_jpg_14_jpg.rf.70c3ce46b74cee515e2d37cde8fc0202.jpg: 640x640 4 faces, 112.7ms
# Speed: 1.0ms pre-process, 112.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\1288788-une-employee-aide-des-voyageurs-en-provenance-de-chine-le-26-janvier-2020-a-l-aeroport-de-roissy_jpg.rf.55458647417fc55d575967c5ef01a74f.jpg: 640x640 7 faces, 143.1ms
# Speed: 1.0ms pre-process, 143.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\1422808187-3291816118_jpg.rf.d732e1de64322f02b57f00aa405323e3.jpg: 640x640 1 face, 93.3ms
# Speed: 1.0ms pre-process, 93.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\1482202839575_jpg.rf.b9d0c8f35100355b00e945fd04c39c3f.jpg: 640x640 4 faces, 91.8ms
# Speed: 0.0ms pre-process, 91.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\1483800496-3386248642_jpg.rf.f21f61bbc9340ac4e346ac1d1f2817f8.jpg: 640x640 4 faces, 94.1ms
# Speed: 1.0ms pre-process, 94.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\15-08608-001_jpg.rf.a908e7d5b9da2ffe5560973f95a3527c.jpg: 640x640 6 faces, 106.4ms
# Speed: 0.9ms pre-process, 106.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\1553605632_9d5877d8_60_jpg.rf.fdebf5a49772d5b48787c690b5048962.jpg: 640x640 8 faces, 89.6ms
# Speed: 1.0ms pre-process, 89.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\20221109_164231_jpg.rf.b9ea4fb106ad4a567ad305c8a2bfb60a.jpg: 640x640 101.0ms
# Speed: 1.0ms pre-process, 101.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\20221109_164330_jpg.rf.b596ea818a9df35e857908ead69f024c.jpg: 640x640 97.6ms
# Speed: 1.0ms pre-process, 97.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\20221109_164420_jpg.rf.2f04182807bff65c25cdc0a563f78a7d.jpg: 640x640 110.7ms
# Speed: 0.0ms pre-process, 110.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\20221109_164524-1-_jpg.rf.921b838f2d90f891c4c5172d2d446b4b.jpg: 640x640 101.2ms
# Speed: 1.0ms pre-process, 101.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\20221109_164558_jpg.rf.b3c826a1f856d253a0b04ca691c20a32.jpg: 640x640 87.4ms
# Speed: 0.0ms pre-process, 87.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\20221109_165214_jpg.rf.95c60d9b0b2566fceceff03dd7044394.jpg: 640x640 101.0ms
# Speed: 0.0ms pre-process, 101.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\2559_jpeg.rf.46b963c9edce17327a5d29fd8ccf1134.jpg: 640x640 5 faces, 92.3ms
# Speed: 1.0ms pre-process, 92.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\ashton-video_mov-55_jpg.rf.c9f962e3cc5ed2bfb08e4bf70b64f036.jpg: 640x640 1 face, 98.9ms
# Speed: 1.0ms pre-process, 98.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\download_jpeg_jpg.rf.a4e0e4736841e8dfc935c790f5195ae7.jpg: 640x640 1 face, 124.6ms
# Speed: 0.0ms pre-process, 124.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\face-detection_mp4-25_jpg.rf.f8dd835c93dd70bf10be06d8bd4a98ec.jpg: 640x640 1 face, 94.0ms
# Speed: 0.9ms pre-process, 94.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\face-detection_mp4-2_jpg.rf.4ecab99213311bf92827e04ff6507cba.jpg: 640x640 1 face, 94.6ms
# Speed: 0.0ms pre-process, 94.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\face-detection_mp4-32_jpg.rf.3399bd9bd347731844d18f131d9781a7.jpg: 640x640 1 face, 90.4ms
# Speed: 1.0ms pre-process, 90.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\face-detection_mp4-4_jpg.rf.de267863a0836f6bf7e92beaaead372e.jpg: 640x640 1 face, 96.6ms
# Speed: 1.0ms pre-process, 96.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-102_jpg.rf.a929532f15cc203ee948007330368bef.jpg: 640x640 1 face, 96.5ms
# Speed: 1.0ms pre-process, 96.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-118_jpg.rf.99efb242170bd6c6da83442697627470.jpg: 640x640 1 face, 116.9ms
# Speed: 1.0ms pre-process, 116.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-122_jpg.rf.48f2f25a31bd1f81657a0c9903a84efe.jpg: 640x640 1 face, 111.7ms
# Speed: 0.0ms pre-process, 111.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-126_jpg.rf.fdaf22d02b7ad71e4554578c2bb621ef.jpg: 640x640 105.5ms
# Speed: 1.0ms pre-process, 105.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-135_jpg.rf.c50c5d95d573de49b57bf0fdeccd7024.jpg: 640x640 1 face, 91.9ms
# Speed: 0.9ms pre-process, 91.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-13_jpg.rf.bd7e6e20d4897797c3594be39478ffc0.jpg: 640x640 2 faces, 114.6ms
# Speed: 0.0ms pre-process, 114.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-143_jpg.rf.2fb8124dad3e2f6c4dc6ef7788c481a5.jpg: 640x640 1 face, 94.1ms
# Speed: 0.0ms pre-process, 94.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-148_jpg.rf.dea78d2a473d7930a87bdfeb48150fca.jpg: 640x640 1 face, 91.4ms
# Speed: 0.0ms pre-process, 91.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-149_jpg.rf.6bb15e4aee0313e39b8765d482264b34.jpg: 640x640 2 faces, 91.0ms
# Speed: 1.0ms pre-process, 91.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-20_jpg.rf.549b9336d914405e0b7cae40ffe18412.jpg: 640x640 2 faces, 88.4ms
# Speed: 1.0ms pre-process, 88.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-30_jpg.rf.dbd5c9e24ff51be7dffe9dcf1e434a12.jpg: 640x640 2 faces, 112.7ms
# Speed: 1.0ms pre-process, 112.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-33_jpg.rf.3d8117fe60612d0ccbb96ac3b54f0565.jpg: 640x640 2 faces, 91.8ms
# Speed: 1.0ms pre-process, 91.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-39_jpg.rf.8106435863dfa37d1c8ebeffef20a425.jpg: 640x640 2 faces, 97.0ms
# Speed: 1.0ms pre-process, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-3_jpg.rf.bb42d56b7cc101bd41a13e2530824a0c.jpg: 640x640 1 face, 109.5ms
# Speed: 0.9ms pre-process, 109.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-49_jpg.rf.14d5cdf89d249c3a5a53d514565bc713.jpg: 640x640 2 faces, 105.9ms
# Speed: 1.0ms pre-process, 105.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-92_jpg.rf.655bb88ef65428d936f57c4df4c5485d.jpg: 640x640 1 face, 108.9ms
# Speed: 1.0ms pre-process, 108.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\gravitate-faces_mp4-9_jpg.rf.39664a1dcb2416de37c19ef3af2c0c14.jpg: 640x640 1 face, 97.8ms
# Speed: 0.0ms pre-process, 97.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\hand-signs-for-alex_mp4-57_jpg.rf.0174af29dfda18f2fb75f4feeaf39a25.jpg: 640x640 1 face, 103.1ms
# Speed: 1.0ms pre-process, 103.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\Image-from-iOS_MOV-31_jpg.rf.6726561f613f63559773497b6c2626e0.jpg: 640x640 1 face, 125.5ms
# Speed: 1.0ms pre-process, 125.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_4920_mov-12_jpg.rf.b1303aade98b1060acc6d1810aa71354.jpg: 640x640 1 face, 113.5ms
# Speed: 1.0ms pre-process, 113.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_4920_mov-3_jpg.rf.0fa45ad0a4de14e1562e50d434a3ab47.jpg: 640x640 1 face, 106.2ms
# Speed: 0.9ms pre-process, 106.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_4921-2_mp4-103_jpg.rf.a9b7f68eb84f0ffee9bdc886e5557cd1.jpg: 640x640 1 face, 90.4ms
# Speed: 1.0ms pre-process, 90.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_4921-2_mp4-107_jpg.rf.fad409a4b4712e207998c19b8ac8ffe9.jpg: 640x640 1 face, 103.1ms
# Speed: 2.0ms pre-process, 103.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_4921-2_mp4-113_jpg.rf.493ecd789ceab4e7e6fd8c04e5b2eea1.jpg: 640x640 1 face, 94.4ms
# Speed: 0.9ms pre-process, 94.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_4921-2_mp4-127_jpg.rf.bdf9cb24b2784ef10eee23abc1242037.jpg: 640x640 1 face, 90.4ms
# Speed: 1.0ms pre-process, 90.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_4921-2_mp4-24_jpg.rf.629eef3fb903e4492066e4176325424d.jpg: 640x640 1 face, 92.0ms
# Speed: 0.0ms pre-process, 92.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_4921-2_mp4-31_jpg.rf.8cad07da7d21ec7b28137e52d73de170.jpg: 640x640 1 face, 90.3ms
# Speed: 1.0ms pre-process, 90.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_4921-2_mp4-41_jpg.rf.c8a0e54a949a23e0a1eb1c7f0e51971e.jpg: 640x640 1 face, 94.6ms
# Speed: 1.0ms pre-process, 94.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_4921-2_mp4-57_jpg.rf.401e129cde61038969828eb030370039.jpg: 640x640 1 face, 94.3ms
# Speed: 0.0ms pre-process, 94.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_4921-2_mp4-5_jpg.rf.ddcd67602e5140c2ad57bf3862967787.jpg: 640x640 1 face, 94.6ms
# Speed: 1.0ms pre-process, 94.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_4921-2_mp4-88_jpg.rf.b0e71dce67f722ccc5ba43a798085992.jpg: 640x640 1 face, 92.2ms
# Speed: 1.5ms pre-process, 92.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_4921-2_mp4-97_jpg.rf.cd5e6432a2ac0424154bc2ee3cd9eb7c.jpg: 640x640 1 face, 92.6ms
# Speed: 1.0ms pre-process, 92.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_5490_mp4-11_jpg.rf.86d40023b737c3a327232b0f057a62a4.jpg: 640x640 91.8ms
# Speed: 1.0ms pre-process, 91.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_5490_mp4-19_jpg.rf.c1862ae9d6b8d462cf6e166c98c10eca.jpg: 640x640 1 face, 91.5ms
# Speed: 1.0ms pre-process, 91.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_5490_mp4-1_jpg.rf.ac7f26f9032fc24028fed43bd714ab51.jpg: 640x640 90.1ms
# Speed: 0.0ms pre-process, 90.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_5491_mp4-3_jpg.rf.c622260d3c4130bc1f465bee974403ff.jpg: 640x640 92.9ms
# Speed: 1.0ms pre-process, 92.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\IMG_5491_mp4-8_jpg.rf.024e19276b9a41566175f13c60c9857b.jpg: 640x640 2 faces, 90.2ms
# Speed: 1.0ms pre-process, 90.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\Inside-merge_mov-12_jpg.rf.a70c50e61ad64703ccdad1e45f957265.jpg: 640x640 95.3ms
# Speed: 1.0ms pre-process, 95.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\Inside-merge_mov-21_jpg.rf.9c70d3d873ec5e97db1c117ae7b93a89.jpg: 640x640 1 face, 93.0ms
# Speed: 0.0ms pre-process, 93.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\Inside-merge_mov-27_jpg.rf.a78fd81c30722372f79f40a801dd8269.jpg: 640x640 92.7ms
# Speed: 1.0ms pre-process, 92.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\Inside-merge_mov-30_jpg.rf.3f216de3daaff897e23a7474626d0770.jpg: 640x640 91.6ms
# Speed: 1.0ms pre-process, 91.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\Inside-merge_mov-58_jpg.rf.4a05351fcc3b5dd356dc1b3a5721727b.jpg: 640x640 94.7ms
# Speed: 1.0ms pre-process, 94.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\istockphoto-1270066655-612x612_jpg.rf.59980d6953f060cb343628b0ce132a2d.jpg: 640x640 4 faces, 91.8ms
# Speed: 1.0ms pre-process, 91.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\Mask-detector1_mov-14_jpg.rf.a87bb3080366eee10113034a609c16de.jpg: 640x640 2 faces, 100.4ms
# Speed: 1.0ms pre-process, 100.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\Mask-detector1_mov-23_jpg.rf.982232908c039952b50134a1f2ec5382.jpg: 640x640 1 face, 91.4ms
# Speed: 0.9ms pre-process, 91.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\Mask-detector1_mov-27_jpg.rf.6efecd11b441599007cc57ea95e04d0d.jpg: 640x640 1 face, 91.2ms
# Speed: 1.0ms pre-process, 91.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\Mask-detector1_mov-53_jpg.rf.cae536c80993053afa3a001d8f1a44eb.jpg: 640x640 1 face, 90.1ms
# Speed: 1.0ms pre-process, 90.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-no-mask_mov-10_jpg.rf.9f096c5316d747e4b6694483ebdddab8.jpg: 640x640 1 face, 105.9ms
# Speed: 0.0ms pre-process, 105.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-no-mask_mov-21_jpg.rf.3d816c05a73bb7a333690a6349a76e0c.jpg: 640x640 1 face, 92.7ms
# Speed: 1.0ms pre-process, 92.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-no-mask_mov-36_jpg.rf.e73aa0f4a48278767e0f5ffeaadd2fd8.jpg: 640x640 1 face, 93.5ms
# Speed: 0.0ms pre-process, 93.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-no-mask_mov-38_jpg.rf.3b459895ac4c9addaf28ef5ae8ccbf73.jpg: 640x640 1 face, 91.3ms
# Speed: 1.0ms pre-process, 91.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-no-mask_mov-50_jpg.rf.b4afd2716df4211f7290277abe5175f1.jpg: 640x640 1 face, 91.7ms
# Speed: 1.6ms pre-process, 91.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-no-mask_mov-56_jpg.rf.dec87ff66c920f4db27c20c20e1da673.jpg: 640x640 1 face, 91.1ms
# Speed: 1.0ms pre-process, 91.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-no-mask_mov-6_jpg.rf.1746a5fcaa6267c2aafd21869f8fd6bf.jpg: 640x640 1 face, 91.3ms
# Speed: 0.0ms pre-process, 91.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-no-mask_mov-71_jpg.rf.723a88ca9dcd0334f850de28f0d98375.jpg: 640x640 1 face, 95.4ms
# Speed: 1.0ms pre-process, 95.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-no-mask_mov-80_jpg.rf.6f7fb84cbf719628043c530307321b3a.jpg: 640x640 1 face, 105.0ms
# Speed: 1.1ms pre-process, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-wearing-1632931966866_png_jpg.rf.f5d9be6dc97e583bd8ce44ff85dcb367.jpg: 640x640 4 faces, 92.2ms
# Speed: 1.0ms pre-process, 92.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-wearing-1632932097427_png_jpg.rf.19217f88e9c977e195dfe74b96604f8c.jpg: 640x640 3 faces, 93.5ms
# Speed: 1.0ms pre-process, 93.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-wearing-1632932267592_png_jpg.rf.06a4c51e15046ab182b54069f7c9e844.jpg: 640x640 1 face, 93.7ms
# Speed: 1.0ms pre-process, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-wearing-1632933579037_png_jpg.rf.f0b73c1dcb02cd5c4ff581509fea4cac.jpg: 640x640 3 faces, 95.2ms
# Speed: 0.9ms pre-process, 95.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-wearing-1632937520400_png_jpg.rf.2b7acdc74125ac087fa9c53c9b15e946.jpg: 640x640 1 face, 91.3ms
# Speed: 1.0ms pre-process, 91.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-wearing-1632937587369_png_jpg.rf.41a691b91a580ea1f8a0b7ed5e43f52b.jpg: 640x640 1 face, 86.2ms
# Speed: 1.0ms pre-process, 86.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-wearing-1632937711552_png_jpg.rf.a7b25c3ea90926461bca2eba1987cbe1.jpg: 640x640 1 face, 86.3ms
# Speed: 0.6ms pre-process, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-wearing-1632937724099_png_jpg.rf.ba674a1abd2e9b6ed7f3c4250b53a776.jpg: 640x640 1 face, 101.4ms
# Speed: 0.0ms pre-process, 101.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-wearing-1632937831241_png_jpg.rf.a1e2acace9b5996d239fb3303ab021d5.jpg: 640x640 1 face, 92.0ms
# Speed: 1.0ms pre-process, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-wearing-1632937938545_png_jpg.rf.e04f6aa6fe0df71140cd02e68ad97a24.jpg: 640x640 1 face, 99.8ms
# Speed: 0.0ms pre-process, 99.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-wearing-1632938044674_png_jpg.rf.566c57b774194f0a4b528b28131bf86c.jpg: 640x640 1 face, 93.3ms
# Speed: 1.0ms pre-process, 93.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-wearing-1632938112706_png_jpg.rf.db469d2ea8744f383ab5987c1fa3ff0a.jpg: 640x640 1 face, 100.1ms
# Speed: 1.0ms pre-process, 100.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-wearing-1632938125416_png_jpg.rf.c49efac7a67342ba7ff0be808dbbd14a.jpg: 640x640 1 face, 92.8ms
# Speed: 1.0ms pre-process, 92.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-wearing-1632939814594_png_jpg.rf.d4b8f3ff3ad0000cbfd83e588524aac1.jpg: 640x640 1 face, 94.9ms
# Speed: 1.0ms pre-process, 94.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\mask-wearing-1632939984654_png_jpg.rf.06d659254a36b6439e813c986a1f92e9.jpg: 640x640 1 face, 87.1ms
# Speed: 1.0ms pre-process, 87.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\Mask2_mov-19_jpg.rf.cf4b2629d3a085fe428d83f9fb7bcfb6.jpg: 640x640 1 face, 99.3ms
# Speed: 1.0ms pre-process, 99.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\Mask2_mov-38_jpg.rf.bcef090a8ffbdbc2fc3957e46b08ff5b.jpg: 640x640 1 face, 88.5ms
# Speed: 0.0ms pre-process, 88.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\Mask2_mov-52_jpg.rf.3942d9c0f13e2b74285674078fcd0c3a.jpg: 640x640 1 face, 90.4ms
# Speed: 1.0ms pre-process, 90.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\Mask2_mov-53_jpg.rf.3c49092cd804791b6843660ab3338200.jpg: 640x640 1 face, 86.3ms
# Speed: 1.1ms pre-process, 86.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\Mask2_mov-56_jpg.rf.75acdf7e324b4a6a47f73f0817163503.jpg: 640x640 1 face, 102.3ms
# Speed: 1.0ms pre-process, 102.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Ultralytics YOLOv8.0.39  Python-3.9.13 torch-1.13.1+cpu CPU
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 D:\Projects\ProgressSoft_Assignment\Problem1\roboflow_data\test\images\Mask2_mov-62_jpg.rf.53533d91e1a32019cb93de590330418d.jpg: 640x640 1 face, 90.2ms
# Speed: 0.9ms pre-process, 90.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
print(f"IoU threshold: {0.1}")
print(f"Precision: {(precision * 100 ).round(3)}%")
print(f"recall: {(recall* 100).round(3)}%")
print(f"IoU: {(iou * 100).round(3)}%")
# Out:
# IoU threshold: 0.1
# Precision: 4.412%
# recall: 4.027%
# IoU: 4.511%
